# %% [markdown]
# # Formation sur pandas

# %%
import pandas as pd 
df = pd.read_csv('survey_results_public.csv')

# %% [markdown]
# #### Pour afficher un certain nombre de ligne

# %%
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %% [markdown]
# #### Pour afficher les dernières lignes

# %%
df.tail(10)
# Out:
#        ResponseId                      MainBranch  \
# 83429       83430     I code primarily as a hobby
# 83430       83431  I am a developer by profession
# 83431       83432  I am a developer by profession
# 83432       83433  I am a developer by profession
# 83433       83434  I am a developer by profession
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# ...

# %% [markdown]
# #### La fonction ci-dessous est connaitre le nombre de colonnes et de lignes

# %%
df.shape
# Out:
# (83439, 48)

# %% [markdown]
# ### df.info() est une méthode pour connaitre le type de chaque colonne (Entier / Objet / String / etc ...) et connaitre le nombre de ligne non null dans chaque colonne

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %% [markdown]
# #### Pour afficher toutes les colonnes

# %%
pd.set_option('display.max_columns', 85)

# %% [markdown]
# #### Pour afficher toutes les lignes

# %%
pd.set_option('display.max_rows', 20)

# %%
schema_df = pd.read_csv('./survey_results_schema.csv')
schema_df
# Out:
#        qid         qname                                           question  \
# 0    QID16            S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12      MetaInfo                                  Browser Meta Info
# ..     ...           ...                                                ...
# 46  QID132  SurveyLength  How do you feel about the length of the survey...
# 47  QID133    SurveyEase  How easy or difficult was this survey to compl...
#
#     force_resp  type selector
# 0        False    DB       TB
# 1        False  Meta  Browser
# ..         ...   ...      ...
# 46       False    MC     MAVR
# 47       False    MC     MAVR
#
# [48 rows x 6 columns]

# %% [markdown]
# df.Country

# %%
df.groupby('Age1stCode').count()
# Out:
#                       ResponseId  MainBranch  Employment  Country  US_State  \
# Age1stCode
# 11 - 17 years              44170       44170       44119    44170      7834
# 18 - 24 years              20065       20065       20054    20065      2730
# 25 - 34 years               4199        4199        4197     4199       728
# 35 - 44 years               1312        1312        1312     1312       221
# 45 - 54 years                544         544         543      544       103
# 5 - 10 years               11720       11720       11691    11720      3038
# 55 - 64 years                245         245         244      245        66
# Older than 64 years           83          83          82       83        18
# Younger than 5 years         905         905         900      905       153
#
#                       UK_Country  EdLevel  LearnCode  YearsCode  YearsCodePro  \
# Age1stCode
# 11 - 17 years               2244    44086      44028      43419         32308
# ...
