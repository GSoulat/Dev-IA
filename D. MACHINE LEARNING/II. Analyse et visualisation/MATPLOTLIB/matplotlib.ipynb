# %% [markdown]
# # FORMATION - UTILISATION DE MATPLOTLIB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
black_friday = pd.read_csv('BlackFriday.csv')
black_friday
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
black_friday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
black_friday.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # Création d'un graphique vide

# %%
plt.plot()
plt.draw()

# %%
Age_groupe = black_friday.groupby('Age')

# %%
Age_groupe.count()
# Out:
#        User_ID  Product_ID  Gender  Occupation  City_Category  \
# Age
# 0-17     14707       14707   14707       14707          14707
# 18-25    97634       97634   97634       97634          97634
# 26-35   214690      214690  214690      214690         214690
# 36-45   107499      107499  107499      107499         107499
# 46-50    44526       44526   44526       44526          44526
# 51-55    37618       37618   37618       37618          37618
# 55+      20903       20903   20903       20903          20903
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# Age
# 0-17                        14707           14707               14707
# 18-25                       97634           97634               97634
# 26-35                      214690          214690              214690
# 36-45                      107499          107499              107499
# 46-50                       44526           44526               44526
# ...

# %%
achats_clients = dict()
for age, group in Age_groupe:
    achats_clients[age] = sum(group['Purchase'])
    
achats_clients
# Out:
# {'0-17': 132659006,
#  '18-25': 901669280,
#  '26-35': 1999749106,
#  '36-45': 1010649565,
#  '46-50': 413418223,
#  '51-55': 361908356,
#  '55+': 197614842}

# %%
plt.plot(achats_clients.keys(), achats_clients.values())
plt.draw()

# %%
plt.plot(achats_clients.keys(), achats_clients.values(), marker = "x",)
plt.draw()

# %%
plt.plot(achats_clients.keys(), achats_clients.values(), marker = "x", linestyle = "")
plt.draw()

# %% [markdown]
# ## Ajout de label

# %%
plt.plot(achats_clients.keys(), achats_clients.values(), marker = "x", linestyle = "", color = "red")
plt.xlabel("Catégories d'age", color = "white", fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes", color = "white" , fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", color = "white" , fontsize = 15, fontweight = "bold")
plt.draw()

# %%
plt.figure(figsize=(5, 5), layout='constrained') # Pour choisir la taille du graphique
plt.plot(achats_clients.keys(), achats_clients.values(), marker = "x", linestyle = "", color = "red")
plt.xlabel("Catégories d'age", color = "white", fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes", color = "white" , fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", color = "white" , fontsize = 15, fontweight = "bold")
plt.draw()

# %% [markdown]
# # Pour créer des nuages de point

# %%
plt.rcParams["figure.figsize"]=[16,9] # Pour agrandir le graphique de façon global
plt.scatter(achats_clients.keys(), achats_clients.values(), color = "red")
plt.xlabel("Catégories d'age", color = "white", fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes", color = "white" , fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", color = "white" , fontsize = 15, fontweight = "bold")
plt.draw()

# %% [markdown]
# # Pour faire varier la couleur en fonction du nombre

# %%
plt.rcParams["figure.figsize"]=[16,9]
plt.scatter(achats_clients.keys(), achats_clients.values(), c = list(achats_clients.values()))
plt.xlabel("Catégories d'age", color = "white", fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes", color = "white" , fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", color = "white" , fontsize = 15, fontweight = "bold")
plt.draw()

# %% [markdown]
# # Pour changer la couleur par défaut avec la fonction `cmap`

# %% [markdown]
# ## Pour changer le fonds du graphique de couleur

# %%
plt.rcParams["figure.figsize"]=[16,9]

fig = plt.figure()
fig.patch.set_facecolor('grey') # Pour changer le fond couleur du graphique
plt.scatter(achats_clients.keys(), achats_clients.values(), c = list(achats_clients.values()), cmap="seismic")
plt.xlabel("Catégories d'age",fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes",  fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , fontsize = 15, fontweight = "bold") # place le titre à une hauteur de 1.05 de plus par rapport au graphique
plt.draw()

# %% [markdown]
# ## d'autre fonction cmap [link](https://matplotlib.org/stable/tutorials/colors/colormaps.html)

# %%
fig = plt.figure()
fig.patch.set_facecolor('blue') # Pour changer le fond couleur du graphique
plt.scatter(achats_clients.keys(), achats_clients.values(), c = list(achats_clients.values()), cmap="seismic")
plt.xlabel("Catégories d'age",fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes",  fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="yellow", fontsize = 20, fontweight = "bold") # place le titre à une hauteur de 1.05 de plus par rapport au graphique
plt.colorbar(orientation = "horizontal") # pour ajouter un bar de couleur en dessous du graphique
plt.draw()

# %%
fig = plt.figure()
fig.patch.set_facecolor('blue') # Pour changer le fond couleur du graphique
plt.scatter(achats_clients.keys(), achats_clients.values(), c = list(achats_clients.values()), cmap="seismic", marker = "D")
plt.xlabel("Catégories d'age",fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes",  fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="yellow", fontsize = 20, fontweight = "bold") # place le titre à une hauteur de 1.05 de plus par rapport au graphique
plt.colorbar(orientation = "vertical") # pour ajouter un bar de couleur en dessous du graphique
plt.draw()

# %% [markdown]
# ## Pour agrandir la taille des points

# %%
fig = plt.figure()
fig.patch.set_facecolor('blue') # Pour changer le fond couleur du graphique
plt.scatter(achats_clients.keys(), achats_clients.values(), c = list(achats_clients.values()), cmap="seismic", marker = "D", s=100)
plt.xlabel("Catégories d'age",fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes",  fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="yellow", fontsize = 20, fontweight = "bold") # place le titre à une hauteur de 1.05 de plus par rapport au graphique
plt.colorbar() # pour ajouter un bar de couleur en dessous du graphique
plt.draw()

# %% [markdown]
# # Pour enregistrer un graphique en png

# %%
fig = plt.figure()
fig.patch.set_facecolor('blue') # Pour changer le fond couleur du graphique
plt.scatter(achats_clients.keys(), achats_clients.values(), c = list(achats_clients.values()), cmap="seismic", marker = "D", s=100)
plt.xlabel("Catégories d'age",fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes",  fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="yellow", fontsize = 20, fontweight = "bold") # place le titre à une hauteur de 1.05 de plus par rapport au graphique
plt.colorbar() # pour ajouter un bar de couleur en dessous du graphique
plt.draw()
plt.savefig("nom_graphique.png", bbox_inches = "tight") # Pour sauvegarder mon fichier

# %% [markdown]
# # Divers graphique

# %% [markdown]
# ## Bar plot

# %%
data = black_friday["Gender"].value_counts()
data
# Out:
# M    405380
# F    132197
# Name: Gender, dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
fig = plt.figure()
fig.patch.set_facecolor('yellow') # Pour changer le fond couleur du graphique
plt.bar(data.index, data,  color = ['blue','red'])
plt.xlabel("Sexe de l'acheteur",fontsize = 15, fontweight = "bold", color = 'blue')
plt.ylabel("Nombre d'acheteurs",  fontsize = 15, fontweight = "bold" , color = 'red')
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="green", fontsize = 20, fontweight = "bold")
plt.draw()

# %% [markdown]
# ## Box plot

# %%
fig = plt.figure()
fig.patch.set_facecolor('grey') # Pour changer le fond couleur du graphique
plt.boxplot(black_friday["Purchase"])
plt.xlabel("Sexe de l'acheteur",fontsize = 15, fontweight = "bold", color = 'white')
plt.ylabel("Nombre d'acheteurs",  fontsize = 15, fontweight = "bold" , color = 'white')
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="white", fontsize = 20, fontweight = "bold")
plt.draw()

# %% [markdown]
# ### Changer la fonction x `xticks`

# %%
fig = plt.figure()
fig.patch.set_facecolor('grey') # Pour changer le fond couleur du graphique
plt.boxplot(black_friday["Purchase"])
plt.xticks([1], ["Ventes"], color="red",fontsize = 20, fontweight = "bold")
plt.xlabel("Sexe de l'acheteur",fontsize = 15, fontweight = "bold", color = 'white')
plt.ylabel("Nombre d'acheteurs",  fontsize = 15, fontweight = "bold" , color = 'white')
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="white", fontsize = 20, fontweight = "bold")
plt.draw()

# %% [markdown]
# ## Camenbert (pie chart)

# %%
data = black_friday["Age"].value_counts()
data
# Out:
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: Age, dtype: int64

# %%
plt.rcParams["figure.figsize"]=[9,9]
fig = plt.figure()
fig.patch.set_facecolor('grey') # Pour changer le fond couleur du graphique
plt.pie(data.values, labels=data.index, autopct='%1.1f%%', shadow=True, startangle=380)
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="white", fontsize = 20, fontweight = "bold")
plt.draw()

# %% [markdown]
# ## Mettre un graphique dans un graphique

# %%
plt.rcParams["figure.figsize"]=[9,9]
fig = plt.figure()
fig.patch.set_facecolor('grey')
plt.subplot(211)
plt.bar(data.index, data,  color = ['blue','red'])
plt.xlabel("Sexe de l'acheteur",fontsize = 15, fontweight = "bold", color = 'blue')
plt.ylabel("Nombre d'acheteurs",  fontsize = 15, fontweight = "bold" , color = 'red')
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="green", fontsize = 20, fontweight = "bold")

plt.subplot(212)
plt.boxplot(black_friday["Purchase"])
plt.xticks([1], ["Ventes"], color="red",fontsize = 20, fontweight = "bold")
plt.tight_layout()
plt.draw()

# %%
plt.rcParams["figure.figsize"]=[9,9]
fig = plt.figure()
fig.patch.set_facecolor('grey')
plt.subplot(221)
plt.bar(data.index, data,  color = ['blue','red'])
plt.xlabel("Sexe de l'acheteur",fontsize = 15, fontweight = "bold", color = 'blue')
plt.ylabel("Nombre d'acheteurs",  fontsize = 15, fontweight = "bold" , color = 'red')
plt.xticks(rotation="vertical") # Pour mettre les valeurs d'un axe a la vertical
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="green", fontsize = 20, fontweight = "bold")

plt.subplot(222)
plt.boxplot(black_friday["Purchase"])
plt.xticks([1], ["Ventes"], color="red",fontsize = 20, fontweight = "bold")

plt.subplot(212)

plt.scatter(achats_clients.keys(), achats_clients.values(), c = list(achats_clients.values()), cmap="seismic", marker = "D", s=100)
plt.xlabel("Catégories d'age",fontsize = 15, fontweight = "bold")
plt.ylabel("Somme totale des ventes",  fontsize = 15, fontweight = "bold")
plt.title("Somme totale des ventes effectuées par catégories d'age", y=1.05 , color="yellow", fontsize = 20, fontweight = "bold") # place le titre à une hauteur de 1.05 de plus par rapport au graphique
plt.colorbar() # pour ajouter un bar de couleur en dessous du graphique

plt.tight_layout()
plt.draw()
