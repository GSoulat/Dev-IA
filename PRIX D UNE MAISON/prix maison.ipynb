# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('kc_house_data.csv', parse_dates=[2], dtype={'price':np.int8})
df['date']= pd.to_datetime(df['date'])
df['price'] = df['price'].astype(float, errors = 'raise')
df.head(10)
# Out:
#            id       date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13   221900.0         3       1.00         1180
# 1  6414100192 2014-12-09   538000.0         3       2.25         2570
# 2  5631500400 2015-02-25   180000.0         2       1.00          770
# 3  2487200875 2014-12-09   604000.0         4       3.00         1960
# 4  1954400510 2015-02-18   510000.0         3       2.00         1680
# 5  7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6  1321400060 2014-06-27   257500.0         3       2.25         1715
# 7  2008000270 2015-01-15   291850.0         3       1.50         1060
# 8  2414600126 2015-04-15   229500.0         3       1.00         1780
# 9  3793500160 2015-03-12   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
print(df['date'].min())
print(df['date'].max())
# Out:
# 2014-05-02 00:00:00
# 2015-05-27 00:00:00

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
sns.histplot(data = df, x = 'price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df['price_log'] = np.log(df['price'])
df['price_log']
# Out:
# 0        12.309982
# 1        13.195614
# 2        12.100712
# 3        13.311329
# 4        13.142166
#            ...
# 21608    12.793859
# 21609    12.899220
# 21610    12.904459
# 21611    12.899220
# 21612    12.691580
# Name: price_log, Length: 21613, dtype: float64

# %%
df.head(5)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# ...

# %%
df['date'] = (df['date'] - df['date'].min()).dt.days

# %%
df
# Out:
#                id  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520   164  221900.0         3       1.00         1180      5650
# 1      6414100192   221  538000.0         3       2.25         2570      7242
# 2      5631500400   299  180000.0         2       1.00          770     10000
# 3      2487200875   221  604000.0         4       3.00         1960      5000
# 4      1954400510   292  510000.0         3       2.00         1680      8080
# ...           ...   ...       ...       ...        ...          ...       ...
# 21608   263000018    19  360000.0         3       2.50         1530      1131
# 21609  6600060120   297  400000.0         4       2.50         2310      5813
# 21610  1523300141    52  402101.0         2       0.75         1020      1350
# 21611   291310100   259  400000.0         3       2.50         1600      2388
# 21612  1523300157   166  325000.0         2       0.75         1020      1076
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'price_log'],
#       dtype='object')

# %% [markdown]
# Pour retourner la liste des colonnes contenant un `float`

# %%
df.select_dtypes(include=['float']).columns.tolist()
# Out:
# ['price', 'bathrooms', 'floors', 'lat', 'long', 'price_log']

# %% [markdown]
# Pour retourner la liste des colonnes contenant un `int`

# %%
df.select_dtypes(include=['int']).columns.tolist()
# Out:
# ['id',
#  'date',
#  'bedrooms',
#  'sqft_living',
#  'sqft_lot',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# Pour retourner la liste des colonnes contenant un `object` (dans ce cas la il n'y a pas d'object)

# %%
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# []

# %% [markdown]
# Position géographique

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"
import plotly.express as px 
import plotly.graph_objs as go
map_fig = px.scatter_geo(df, lat=df['lat'], lon=df['long'], hover_name="price", size="bathrooms", color="sqft_living", scope="usa", title = 'Lieu des maisons vendu')
map_fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
for col in df.columns:
    sns.set(rc={'figure.figsize':(4,4)})
    with sns.axes_style('ticks', {'figure.facecolor': 'yellow', 'font.family': ['sans-serif'],'font.sans-serif': ['Arial',
  'DejaVu Sans'], 'axes.grid': True}):
        sns.histplot(data = df, x = col)
        plt.title(col)
        plt.xscale('log')
        plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_2192/1478838463.py:7: UserWarning:
#
# Data has no positive values, and therefore cannot be log-scaled.

# %%
fig = plt.figure(figsize=(7,15))

for col in df.columns:
    df.plot.scatter(x=col ,y='price')
    plt.show()

# df.plot.scatter(x='sqft_living' ,y='price')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
with sns.axes_style('ticks', {'figure.facecolor': 'white'}):
    plt.figure(figsize=(8,8))
    sns.heatmap(df.corr(),cmap="PiYG")
    plt.title("Correlations Between Variables", size=15)
    plt.show()

# %%
pd.set_option('display.max_columns',None)
corrmat = df.corr()
sorted_corrs = corrmat['price'].abs().sort_values()
print(sorted_corrs)
# Out:
# date             0.004357
# id               0.016762
# long             0.021626
# condition        0.036362
# zipcode          0.053203
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price_log        0.891654
# price            1.000000
# Name: price, dtype: float64

# %%
y = df['price']

# %%
dropcolumns = ['price', 'id', 'price_log', 'zipcode','date', 'waterfront','sqft_lot', 'yr_built','yr_renovated','long','sqft_lot15','bedrooms','bathrooms','floors','view','lat','sqft_basement','sqft_above','grade','condition','sqft_living15']
df_X = df.drop(dropcolumns, axis=1)
df_X
# Out:
#        sqft_living
# 0             1180
# 1             2570
# 2              770
# 3             1960
# 4             1680
# ...            ...
# 21608         1530
# 21609         2310
# 21610         1020
# 21611         1600
# 21612         1020
#
# [21613 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split
dr = DummyRegressor()

# %% [markdown]
# ##### X et y doivent avoir 2 dimensions
# ##### X étant les features (les caractéritiques)
# ##### y étant la target

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, y, test_size=0.20, random_state=42)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# %%
dr.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
y_pred = dr.predict(X_test)
y_pred
# Out:
# array([538033.5858155, 538033.5858155, 538033.5858155, ...,
#        538033.5858155, 538033.5858155, 538033.5858155])

# %%
dr.score(X_test, y_test)
# Out:
# -0.000849709800040177

# %% [markdown]
# Méthode Régression Linéaire

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

print(lr.intercept_)
print(lr.coef_)

a0 = lr.intercept_
a1 = lr.coef_
# Out:
# -46580.36228218465
# [281.53574849]

# %%
from sklearn.metrics import mean_squared_error

train_predictions = lr.predict(X_train)
test_predictions = lr.predict(X_test)

train_mse = mean_squared_error(train_predictions, y_train)
test_mse = mean_squared_error(test_predictions, y_test)

train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)

print(train_rmse)
print(test_rmse)
# Out:
# 259630.03519181136
# 276539.1001127958

# %% [markdown]
# Test avec plusieurs colonne

# %%
pd.set_option('display.max_columns',None)
corrmat = df.corr()
sorted_corrs = corrmat['price'].abs().sort_values()

print(sorted_corrs)
# Out:
# date             0.004357
# id               0.016762
# long             0.021626
# condition        0.036362
# zipcode          0.053203
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price_log        0.891654
# price            1.000000
# Name: price, dtype: float64

# %%
strong_corrs = sorted_corrs[sorted_corrs>0.3]
corrmat = df[strong_corrs.index].corr()
plt.figure(figsize=(8,8))
sns.heatmap(corrmat)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Analyse de la heatmap

# %% [markdown]
# Les fortes corrélations sont :
#
# entre sqft_living et sqft_above , bathroom , sqft_living15, grade
# entre price et sqft_living , grade

# %%
final_corr_cols = strong_corrs.drop(['sqft_above', 'sqft_living','price_log'])
df[final_corr_cols.index].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   lat            21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   sqft_basement  21613 non-null  int64
#  3   view           21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living15  21613 non-null  int64
#  6   grade          21613 non-null  int64
#  7   price          21613 non-null  float64
# dtypes: float64(3), int64(5)
# memory usage: 1.3 MB

# %%
final_corr_cols = strong_corrs.drop(['sqft_above', 'sqft_living','price_log'])
features = final_corr_cols.drop(["price"]).index
target = 'price'


print(features)
# Out:
# Index(['lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms',
#        'sqft_living15', 'grade'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.20, random_state=42)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# %%
lr.fit(X_train, y_train)

print(lr.intercept_)
print(lr.coef_)

a0 = lr.intercept_
a1 = lr.coef_
# Out:
# -30665620.69595141
# [6.29840823e+05 4.73535760e+03 1.00337758e+02 9.55691017e+04
#  5.15101905e+04 8.22613999e+01 1.18631108e+05]

# %%
train_predictions_2 = lr.predict(X_train)
test_predictions_2 = lr.predict(X_test)

train_mse_2 = mean_squared_error(train_predictions_2, y_train)
test_mse_2 = mean_squared_error(test_predictions_2, y_test)

train_rmse_2 = np.sqrt(train_mse_2)
test_rmse_2 = np.sqrt(test_mse_2)

print(train_rmse_2)
print(test_rmse_2)
# Out:
# 233215.18483748715
# 246487.45089523745

# %% [markdown]
# Faible variance

# %%
unit_train = (X_train - X_train.min()) / (X_train.max() - X_train.min())
print(unit_train.min())
print(unit_train.max())

sorted_vars = unit_train.var().sort_values()
print(sorted_vars)
# Out:
# lat              0.0
# bedrooms         0.0
# sqft_basement    0.0
# view             0.0
# bathrooms        0.0
# sqft_living15    0.0
# grade            0.0
# dtype: float64
# lat              1.0
# bedrooms         1.0
# sqft_basement    1.0
# view             1.0
# bathrooms        1.0
# sqft_living15    1.0
# grade            1.0
# dtype: float64
# bedrooms         0.000809
# sqft_basement    0.008431
# bathrooms        0.009140
# grade            0.009551
# sqft_living15    0.013787
# view             0.036716
# lat              0.050028
# dtype: float64

# %%
features
# Out:
# Index(['lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms',
#        'sqft_living15', 'grade'],
#       dtype='object')

# %%
features = features.drop(['bedrooms','sqft_basement'])
print(features)
# Out:
# Index(['lat', 'view', 'bathrooms', 'sqft_living15', 'grade'], dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.20, random_state=42)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

train_predictions_3 = lr.predict(X_train)
test_predictions_3 = lr.predict(X_test)

train_mse_3 = mean_squared_error(train_predictions_3, y_train)
test_mse_3 = mean_squared_error(test_predictions_3, y_test)

train_rmse_3 = np.sqrt(train_mse_3)
test_rmse_3 = np.sqrt(test_mse_3)

print(train_rmse_3)
print(test_rmse_3)
# Out:
# 236949.80136807187
# 249798.68030587942

# %% [markdown]
# test avec elacticnet

# %%
from sklearn.linear_model import ElasticNet

# %%
regressor = ElasticNet(alpha = 1, l1_ratio = 0.5)
result = regressor.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.760e+14, tolerance: 1.847e+11

# %%
ytest = regressor.predict(X_test)
ytest
# Out:
# array([ 516283.59662508,  723792.78891438, 1179660.89317683, ...,
#         530396.42921216,  576760.66391926,  557707.74048808])

# %%
score = regressor.score(X_test, ytest)
score
# Out:
# 1.0

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()

# %%
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
ytest = ridge.predict(X_test)
ytest
# Out:
# array([ 511749.46925054,  702697.61301877, 1226554.86425787, ...,
#         527145.3510971 ,  569558.94634458,  547828.63488835])

# %%
scoreRidge = ridge.score(X_test, ytest)
scoreRidge
# Out:
# 1.0

# %% [markdown]
#  Régression linéaire Lasso
