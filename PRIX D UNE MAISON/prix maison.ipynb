# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('kc_house_data.csv', parse_dates=[2], dtype={'price':np.int8})
df['date']= pd.to_datetime(df['date'])
df['price'] = df['price'].astype(float, errors = 'raise')
df.head(10)
# Out:
#            id       date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13   221900.0         3       1.00         1180
# 1  6414100192 2014-12-09   538000.0         3       2.25         2570
# 2  5631500400 2015-02-25   180000.0         2       1.00          770
# 3  2487200875 2014-12-09   604000.0         4       3.00         1960
# 4  1954400510 2015-02-18   510000.0         3       2.00         1680
# 5  7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6  1321400060 2014-06-27   257500.0         3       2.25         1715
# 7  2008000270 2015-01-15   291850.0         3       1.50         1060
# 8  2414600126 2015-04-15   229500.0         3       1.00         1780
# 9  3793500160 2015-03-12   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
# 6      6819     2.0           0     0  ...      7        1715              0
# 7      9711     1.0           0     0  ...      7        1060              0
# 8      7470     1.0           0     0  ...      7        1050            730
# 9      6560     2.0           0     0  ...      7        1890              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
# 5      2001             0    98053  47.6561 -122.005           4760
# 6      1995             0    98003  47.3097 -122.327           2238
# 7      1963             0    98198  47.4095 -122.315           1650
# 8      1960             0    98146  47.5123 -122.337           1780
# 9      2003             0    98038  47.3684 -122.031           2390
#
#    sqft_lot15
# 0        5651
# 1        7639
# 2        8062
# 3        5000
# 4        7503
# 5      101930
# 6        6819
# 7        9711
# 8        8113
# 9        7570
#
# [10 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(15)
# memory usage: 3.5 MB

# %%
print(df['date'].min())
print(df['date'].max())
# Out:
# 2014-05-02 00:00:00
# 2015-05-27 00:00:00

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455698
# std       53.505026      0.138564      0.140828     685.391304   27304.179619
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
sns.histplot(data = df, x = 'price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df['price_log'] = np.log(df['price'])
df['price_log']
# Out:
# 0        12.309982
# 1        13.195614
# 2        12.100712
# 3        13.311329
# 4        13.142166
#            ...
# 21608    12.793859
# 21609    12.899220
# 21610    12.904459
# 21611    12.899220
# 21612    12.691580
# Name: price_log, Length: 21613, dtype: float64

# %%
df.head(5)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15  price_log
# 0        5651  12.309982
# 1        7639  13.195614
# 2        8062  12.100712
# 3        5000  13.311329
# 4        7503  13.142166
#
# [5 rows x 22 columns]

# %%
df['date'] = (df['date'] - df['date'].min()).dt.days

# %%
df
# Out:
#                id  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520   164  221900.0         3       1.00         1180      5650
# 1      6414100192   221  538000.0         3       2.25         2570      7242
# 2      5631500400   299  180000.0         2       1.00          770     10000
# 3      2487200875   221  604000.0         4       3.00         1960      5000
# 4      1954400510   292  510000.0         3       2.00         1680      8080
# ...           ...   ...       ...       ...        ...          ...       ...
# 21608   263000018    19  360000.0         3       2.50         1530      1131
# 21609  6600060120   297  400000.0         4       2.50         2310      5813
# 21610  1523300141    52  402101.0         2       0.75         1020      1350
# 21611   291310100   259  400000.0         3       2.50         1600      2388
# 21612  1523300157   166  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  ...  sqft_above  sqft_basement  yr_built  \
# 0         1.0           0     0  ...        1180              0      1955
# 1         2.0           0     0  ...        2170            400      1951
# 2         1.0           0     0  ...         770              0      1933
# 3         1.0           0     0  ...        1050            910      1965
# 4         1.0           0     0  ...        1680              0      1987
# ...       ...         ...   ...  ...         ...            ...       ...
# 21608     3.0           0     0  ...        1530              0      2009
# 21609     2.0           0     0  ...        2310              0      2014
# 21610     2.0           0     0  ...        1020              0      2009
# 21611     2.0           0     0  ...        1600              0      2004
# 21612     2.0           0     0  ...        1020              0      2008
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0                 0    98178  47.5112 -122.257           1340        5651
# 1              1991    98125  47.7210 -122.319           1690        7639
# 2                 0    98028  47.7379 -122.233           2720        8062
# 3                 0    98136  47.5208 -122.393           1360        5000
# 4                 0    98074  47.6168 -122.045           1800        7503
# ...             ...      ...      ...      ...            ...         ...
# 21608             0    98103  47.6993 -122.346           1530        1509
# 21609             0    98146  47.5107 -122.362           1830        7200
# 21610             0    98144  47.5944 -122.299           1020        2007
# 21611             0    98027  47.5345 -122.069           1410        1287
# 21612             0    98144  47.5941 -122.299           1020        1357
#
#        price_log
# 0      12.309982
# 1      13.195614
# 2      12.100712
# 3      13.311329
# 4      13.142166
# ...          ...
# 21608  12.793859
# 21609  12.899220
# 21610  12.904459
# 21611  12.899220
# 21612  12.691580
#
# [21613 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'price_log'],
#       dtype='object')

# %%
for col in df.columns:
    with sns.axes_style('ticks', {'figure.facecolor': 'grey', 'font.family': ['sans-serif'],'font.sans-serif': ['Arial',
  'DejaVu Sans'], 'axes.grid': True}):
        sns.histplot(data = df, x = col)
        plt.title(col)
        plt.xscale('log')
        plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_5312/1502421252.py:6: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.xscale('log')

# %%
df["zipcode"].value_counts(normalize=True).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='zipcode'>

# %%
df.plot.scatter(x='sqft_living' ,y='price')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split

dr = DummyRegressor()

# %%
y = df['price']

# %%
dropcolumns = ['price', 'id', 'price_log']
df_X = df.drop(dropcolumns, axis=1)
df_X
# Out:
#        date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0       164         3       1.00         1180      5650     1.0           0
# 1       221         3       2.25         2570      7242     2.0           0
# 2       299         2       1.00          770     10000     1.0           0
# 3       221         4       3.00         1960      5000     1.0           0
# 4       292         3       2.00         1680      8080     1.0           0
# ...     ...       ...        ...          ...       ...     ...         ...
# 21608    19         3       2.50         1530      1131     3.0           0
# 21609   297         4       2.50         2310      5813     2.0           0
# 21610    52         2       0.75         1020      1350     2.0           0
# 21611   259         3       2.50         1600      2388     2.0           0
# 21612   166         2       0.75         1020      1076     2.0           0
#
#        view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0         0          3      7        1180              0      1955
# 1         0          3      7        2170            400      1951
# 2         0          3      6         770              0      1933
# 3         0          5      7        1050            910      1965
# 4         0          3      8        1680              0      1987
# ...     ...        ...    ...         ...            ...       ...
# 21608     0          3      8        1530              0      2009
# 21609     0          3      8        2310              0      2014
# 21610     0          3      7        1020              0      2009
# 21611     0          3      8        1600              0      2004
# 21612     0          3      7        1020              0      2008
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0                 0    98178  47.5112 -122.257           1340        5651
# 1              1991    98125  47.7210 -122.319           1690        7639
# 2                 0    98028  47.7379 -122.233           2720        8062
# 3                 0    98136  47.5208 -122.393           1360        5000
# 4                 0    98074  47.6168 -122.045           1800        7503
# ...             ...      ...      ...      ...            ...         ...
# 21608             0    98103  47.6993 -122.346           1530        1509
# 21609             0    98146  47.5107 -122.362           1830        7200
# 21610             0    98144  47.5944 -122.299           1020        2007
# 21611             0    98027  47.5345 -122.069           1410        1287
# 21612             0    98144  47.5941 -122.299           1020        1357
#
# [21613 rows x 19 columns]

# %%
with sns.axes_style('ticks', {'figure.facecolor': 'white'}):
    plt.figure(figsize=(10,8))
    sns.heatmap(df.corr(), cmap="RdBu")
    plt.title("Correlations Between Variables", size=15)
    plt.show()

# %%
df.corr()
# Out:
#                      id      date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000  0.005577 -0.016762  0.001286   0.005160    -0.012258
# date           0.005577  1.000000 -0.004357 -0.016800  -0.034410    -0.034559
# price         -0.016762 -0.004357  1.000000  0.308350   0.525138     0.702035
# bedrooms       0.001286 -0.016800  0.308350  1.000000   0.515884     0.576671
# bathrooms      0.005160 -0.034410  0.525138  0.515884   1.000000     0.754665
# sqft_living   -0.012258 -0.034559  0.702035  0.576671   0.754665     1.000000
# sqft_lot      -0.132109  0.006313  0.089661  0.031703   0.087740     0.172826
# floors         0.018525 -0.022491  0.256794  0.175429   0.500653     0.353949
# waterfront    -0.002721  0.001356  0.266369 -0.006582   0.063744     0.103818
# view           0.011592 -0.001800  0.397293  0.079532   0.187737     0.284611
# condition     -0.023783 -0.050769  0.036362  0.028472  -0.124982    -0.058753
# grade          0.008130 -0.039912  0.667434  0.356967   0.664983     0.762704
# sqft_above    -0.010842 -0.027924  0.605567  0.477600   0.685342     0.876597
# sqft_basement -0.005151 -0.019469  0.323816  0.303093   0.283770     0.435043
# yr_built       0.021380 -0.000355  0.054012  0.154178   0.506019     0.318049
# yr_renovated  -0.016907 -0.024509  0.126434  0.018841   0.050739     0.055363
# zipcode       -0.008224  0.001404 -0.053203 -0.152668  -0.203866    -0.199430
# lat           -0.001891 -0.032856  0.307003 -0.008931   0.024573     0.052529
# long           0.020799 -0.007020  0.021626  0.129473   0.223042     0.240223
# sqft_living15 -0.002901 -0.031515  0.585379  0.391638   0.568634     0.756420
# sqft_lot15    -0.138798  0.002566  0.082447  0.029244   0.087175     0.183286
# price_log     -0.003819 -0.005727  0.891654  0.343561   0.550802     0.695341
#
#                sqft_lot    floors  waterfront      view  ...  sqft_above  \
# id            -0.132109  0.018525   -0.002721  0.011592  ...   -0.010842
# date           0.006313 -0.022491    0.001356 -0.001800  ...   -0.027924
# price          0.089661  0.256794    0.266369  0.397293  ...    0.605567
# bedrooms       0.031703  0.175429   -0.006582  0.079532  ...    0.477600
# bathrooms      0.087740  0.500653    0.063744  0.187737  ...    0.685342
# sqft_living    0.172826  0.353949    0.103818  0.284611  ...    0.876597
# sqft_lot       1.000000 -0.005201    0.021604  0.074710  ...    0.183512
# floors        -0.005201  1.000000    0.023698  0.029444  ...    0.523885
# waterfront     0.021604  0.023698    1.000000  0.401857  ...    0.072075
# lat           -0.135512       0.048858   -0.086419   0.449174
# long           1.000000       0.334605    0.254451   0.049942
# sqft_living15  0.334605       1.000000    0.183192   0.619312
# sqft_lot15     0.254451       0.183192    1.000000   0.091592
# price_log      0.049942       0.619312    0.091592   1.000000
#
# [22 rows x 22 columns]

# %%
with sns.axes_style('ticks', {'figure.facecolor': 'white'}):
    plotScatterMatrix(df1, 20, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5312/3930178855.py in <module>
#       1 with sns.axes_style('ticks', {'figure.facecolor': 'white'}):
# ----> 2     plotScatterMatrix(df1, 20, 10)
#
# NameError: name 'plotScatterMatrix' is not defined

# %% [markdown]
# ##### X et y doivent avoir 2 dimensions
# ##### X étant les features (les caractéritiques)
# ##### y étant la target

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, y, test_size=0.20, random_state=42)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.20, random_state=42)

# %%
dr.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
dr.score(X_test, y_test)
# Out:
# -0.000849709800040177

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([ 456288.97428502,  750729.66741048, 1221826.94406805, ...,
#         415184.82508087,  617232.27165689,  440987.11765364])

# %% [markdown]
# C'est le coefficient de détermination R²

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7020014933826011

# %%
lr.score(X_test, y_test)
# Out:
# 0.7020014933826011

# %% [markdown]
# #### Calculer la performance du modèle en utilisant MSE (Mean Square Error)

# %%
print(np.mean((y_test-y_pred)**2))
# Out:
# 45050434487.87151

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test, y_pred))
# Out:
# 45050434487.87149

# %% [markdown]
# Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(LinearRegression(), X_train, y_train, cv=5, scoring='accuracy')
# Out:
# C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\metrics\_classification.py", line 93, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# array([nan, nan, nan, nan, nan])
