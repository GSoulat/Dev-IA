# %% [markdown]
# ### 1°) Support vector Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
m = 100 #creating 100 samples
X = np.linspace(0,10,m).reshape(m,1)
y = X**2 + np.random.randn(m,1)

# %%
fig = plt.figure()
fig.patch.set_facecolor('blue') 
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
fig = plt.figure()
fig.patch.set_facecolor('blue') 
model = SVR(C=100)
model.fit(X,y)
lr_scrore = model.score(X,y)
predictions = model.predict(X)
print(lr_scrore)
plt.scatter(X,y)
plt.plot(X,predictions, c='r')
# Out:
# 0.9989763625652847
# C:\ProgramData\Anaconda3\envs\envMl\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
